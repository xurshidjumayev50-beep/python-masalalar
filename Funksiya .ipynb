# %%
# Funksiya 
#def bu kalit soz 
#  funksiya har doim birinchi yoziladi 
# return --- funksiyani qaytaruvchisi 
# funksiya birinchi yoziladi keyin funksiyaga murojat qilinadi 
def Funksiya(a,b):
    
    S=a*b
    return S
a=int(input("a="))
b=int(input("b="))
print(Funksiya(a,b))
# Out:
# 20

# %%
# Out:
# 8

# %%
# funksiya 1 

from math import *
def PowerA3(n):
    return n**3
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
d = float(input("d = "))
e = float(input("e = "))
print(PowerA3(a))
print(PowerA3(b))
print(PowerA3(c))
print(PowerA3(d))
print(PowerA3(e))
# Out:
# 8
# 27
# 64
# 68.92099999999998
# 140.608

# %%
# funksiya 2 
def PowerA234(n, m, k):
    print(n**2, n**3, n**4, sep="\n")
    print(m**2, m**3, m**4, sep="\n")
    print(k**2, k**3, k**4, sep="\n")
a = int(input("a = "))
b = int(input("b = "))
c = float(input("c = "))
PowerA234(a, b, c)
# Out:
# 16
# 64
# 256
# 25
# 125
# 625
# 36.0
# 216.0
# 1296.0

# %%
# funksiya 3 
def Mean(a,b,c,d):
    print((a+b)/2,(a*b)**1/2, sep="/n")
    print((a+c)/2,(a*c)**1/2, sep="/n")
    print((a+d)/2,(a*d)**1/2)
a=int(input("a="))
b=int(input("b="))
c=int(input("c="))
d=int(input("d="))
Mean(a,b,c,d)
# Out:
# 3.0/n4.0
# 4.5/n10.0
# 4.5 10.0

# %%
# funksiya  4 
def Triangle(a):
    print("P = ", a * 3, "\nS = ", (a ** 2 * 3 ** (0.5))/4 )
    
a = int(input())
Triangle(a)
# Out:
# P =  12
# S =  6.928203230275509

# %%
# funksiya 5 
def RectPS(x1, y1, x2, y2):
    a = abs(x1 - x2)
    b = abs(y1 - y2)
    P = 2 * (a + b)
    S = a * b
    return P, S
    
x1 = int(input("x1 = "))
y1 = int(input("y1 = "))
x2 = int(input("x2 = "))
y2 = int(input("y2 = "))

print(RectPS(x1, y1, x2, y2))
# Out:
# (8, 3)

# %%
# funksiya 6 
def DigitCountSum(n):

    J=0
    S=0
    while (n>0):
        S +=n%10
        n//=10
        J +=1
        print(J,S)
a=int(input())
DigitCountSum(a)
# Out:
# 1 0
# 2 9
# 3 17
# 4 24
# 5 30
# 6 35
# 7 39
# 8 42
# 9 44
# 10 45

# %%
# funksiya 7 
def InvertDigit(n):
    s=''
    while (n>0):
        q=n%10
        n=n//10
        s+=str(q)

    return int(s)
a=int(input("a="))
print(InvertDigit(a))
# Out:
# 122222221

# %%
# funksiya 8 
def AddRightDigit(k, r):
    k = k * 10 + r
    return k
k = int(input())
r = int(input())
print(AddRightDigit(k, r))
# Out:
# 45

# %%
# funksiya 9
def AddRightDigit(k, r):
    k = k * 10 + r
    return k
k = int(input())
r = int(input())
print(AddRightDigit(k, r))
# Out:
# 45

# %%
# funksiya 10 
def Swap(a,  b):
    a = a + b
    b = a - b
    a = a - b
    return a, b
        
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
d = int(input("d = "))
a, b = Swap(a, b)
c, d = Swap(c, d)
print(a, b, c, d, sep = "\n")
# Out:
# 5
# 1
# 6
# 4

# %%
# funksiya 11 
def Minmax(x, y):
    if(x > y):
        x = x + y
        y = x - y
        x = x - y
    return x, y

x = int(input("x = "))
y = int(input('y = '))
x, y = Minmax(x, y)
print("x = ", x, "y = ", y)
a = int(input("a = "))
b = int(input('b = '))
x, y = Minmax(x, y)
print("a = ", x, "b = ", y)
# Out:
# x =  4 y =  6
# a =  4 b =  6

# %%
# funksiya 12 

def SortInc3(a, b, c):
    if c > b > a and c != a:
        d = a; a = c; c = d
    elif a > c > b and a != b:
        d = b; c = b; b = d
    elif b > c > a and   b != a:
        d = a; a = b
        b = c; c = d
    elif b > a:
        d = a; a = b; b = d
    elif c > a > b and c != b:
        d = b; b = a; a = c; c = d
    return a, b, c
a = int(input())
b = int(input())
c = int(input())
a, b, c = SortInc3(a, b, c)
print(a, b, c, sep = "\n")
# Out:
# 6
# 5
# 4

# %%
# funksiya 13 
def SortInc3(a, b, c):
    d = a + b + c
    c = min(a, b, c)
    a = max(a, b, c)
    b = d - a - c
    return a, b, c
a = int(input())
b = int(input())
c = int(input())
a, b, c = SortInc3(a, b, c)
print(a, b, c, sep = "\n")
# Out:
# 4
# 2
# 1

# %%
# funksiya 14 
def ShiftRight3(a,b,c):
    e = b
    b = a
    a = c
    c = e
    return a,b,c

a=int(input("a="))
b=int(input("b="))
c=int(input("c="))
a,b,c = ShiftRight3(a,b,c)
print(a,b,c, sep= " ")
# Out:
# 3 1 2

# %%
# funksiya 15 
def ShiftLift3(a, b, c):
    e = b
    b = c
    c = a
    a = e
    
    return a, b, c

a = int(input())
b = int(input())
c = int(input())
a, b, c = ShiftLift3(a, b, c)
print(a, b, c, sep = " ")
# Out:
# 2 3 1

# %%
# funksiya 16 
def ishora(n):
    if n < 0:
        return -1
    elif n == 0:
        return 0
    else:
        return 1
        
a = float(input("a = "))
a = ishora(a)
b = float(input("b = "))
b = ishora(b)
print(a+b)
# Out:
# 2

# %%
# funksiya 17 
def ildizlar_soni(a, b, c):
    d = b ** 2 - 4 * a * c
    if d > 0:
        d = 2
    elif d == 0:
        d = 1
    else:
        d = "Haqiqiy yechimi yo'q"
    return d
        
a = int(input())
b = int(input())
c = int(input())

d = ildizlar_soni(a, b, c)
print(d)
# Out:
# 2

# %%
# funksiya 18 
def doira_yuzi(r):
    pi = float(3.1415)
    return r**2 * pi

r = float(input("r = "))
S = doira_yuzi(r)
print(S)
# Out:
# 50.264

# %%
# funksiya 19 
def RingS(r1, r2):
    pi = float(3.1415)
    return pi* (r1 - r2) ** 2
r1 = float(input("r1 = "))
r2 = float(input("r2 = "))
dS = RingS(r1, r2)
print("dS = ", dS)
# Out:
# dS =  3.1415

# %%
# funksiya 20 
def TriangleP(a, b):
    return 2 * (a + b)
a = int(input())
b = int(input())
P = TriangleP(a, b)
print("P = ", P)
# Out:
# P =  12

# %%
# funsksiya 21 
def SumRange1(a, b):
    if b > a:
        return sum(list(range(a, b)))
    else:
        return 0

def SumRange2(a, b):
    if b > a:
        S = 0
        for i in range(a,b):
            S += i
        return S
    else:
        return 0

S1 = SumRange1(1, 10)
S2 = SumRange2(1, 10)
print(S1, "\n", S2)
# Out:
# 45
#  45

# %%
# funksiya 22 
def Calc(a, b, op):
    if (str(op) == "+"):
        return a + b
    elif(str(op) == "-"):
        return a - b
    elif(str(op) == "/"):
        return a / b
    elif(str(op) == "*"):
        return a * b
    else:
        return "Bunday amal yo'q"
    
a = int(input("a = "))
b = int(input("b = "))
c = str(input("Amal kiriting : "))
a = Calc(a, b, c)
print(a)
# Out:
# -1

# %%
# FUKSIYA 23
def Quarter(x, y):
    if (x > 0 and y > 0):
        return 1
    elif(x < 0 and y < 0 ):
        return 3
    elif(x > 0 and y < 0):
        return 4
    elif(x < 0 and y > 0):
        return 2
    else:
        return "Chiziqlar ustida"
    
a = Quarter(5,0)
print(a)
# Out:
# Chiziqlar ustida

# %%
# funksiya 24
def Even(n):
    if n % 2 == 0:
        return "Juft"
    else:
        return "Toq"
n = int(input("n = "))
print(Even(n))
# Out:
# Juft

# %%
# funsiya 25 
def isSquare(n):
    n = int(n)
    if n**(1/2) - int(n**(1/2)) == 0:
        return True
    else:
        return False
n = int(input())
n = isSquare(n)
print(n)
# Out:
# True

# %%
#  funsiya 26 

def isPower5(n):
    if n ** 0.2 - int(n ** 0.2) == 0:
        return True
    else:
        return False
        
    
n = int(input())
n = isPower5(n)
print(n)

# %%
# funsiya 27
def isPowerN(k,n):
    while(k != n and k > n):
        k /= n
    if k == n: 
        return True
    else:
        return False
n = int(input("n = "))
k = int(input("k = "))
n = isPowerN(k ,n)
print(n)
# Out:
# False

# %%
# funksiya 28
def isPrime(n):
    tub = False
    for i in range(2, int(n**0.5)):
        if (n % i != 0 ):
            tub = True
        else:
            tub = False
            break
    return tub
n = isPrime(97)
print(n)
# Out:
# True

# %%
# funksiya 29 
def DigitCount(n):
    j = 0
    while(n > 0):
        n //= 10
        j += 1
    return j
print(DigitCount(12123))
# Out:
# 5

# %%
# funksiya 30 
def DigitN(k, n):
    return k % 10 **n // 10**(n-1)
k1 = int(input("k1 = "))
n1 = int(input("n1 = "))
k2 = int(input("k2 = "))
n2 = int(input("n2 = "))
k3 = int(input("k3 = "))
n3 = int(input("n3 = "))
print(DigitN(k1, n1))
print(DigitN(k2, n2))
print(DigitN(k3, n3))
# Out:
# 0
# 0
# 0

# %%
# funksiya 31
def isPalindrom(n):
    n1 = n
    n2 = 0
    while(n > 0):
        n2 += n % 10
        n2 *= 10
        n //=10
    n2 /= 10
    if n1 == n2:
        return True
    else:
        return False
n = int(input("n = "))
print(isPalindrom(n))
# Out:
# True

# %%
# funksiya 32
def DegTodRad(d):
    pi = 3.1415
    return d *  pi / 180
n = int(input("n = "))
n = DegTodRad(n)
print(n)
# Out:
# 0.06981111111111112

# %%
# funksiya 33
def RadToDeg(n):
    pi = 3.1415
    return n * 180 / pi
n = float(input('n = '))
n = RadToDeg(n)
print(n)
# Out:
# 229.1898774470794

# %%
# funksiya 34 
def Fact(n):
    if n == 1:
        return 1
    else:
        return n * Fact(n - 1)
n = int(input("n = "))
n = Fact(n)
print(n)
# Out:
# 24

# %%
# funksiya 35 
def Fact2(n):
    p = 1
    for i in range(1, n+1):
        p *= i
    return p
    
    
n = int(input("n = "))
n = Fact2(n)
print(n)
# Out:
# 24

# %%
# funksiya 36
def Fib(n):
    a = 0
    b = 1
    if (n == 1):
        return 0
    elif n == 2:
        return 1
    else: 
        k = 2
        for i in range(1,n+1,2):
            a += b
            k += 1
            if k == n:
                return a
                break
            b += a
            k +=1
            if k == n:
                return b
                break
        
            
        

n = int(input('n = '))
n = Fib(n)
print(n)
# Out:
# 2

# %%
# funksiya 37
def Power1(a, b):
    return a**b
a = float(input("a = "))
b = float(input("b = "))
print(Power1(a, b))
# Out:
# 5.684341886080802e+30

# %%
# funksiya 38
def Power2(a, n):
    return a**n
a = float(input("a = "))
b = int(input("b = "))
print(Power2(a, b))
# Out:
# 83019.04405381883

# %%
# funksiya 39]
def Power3(a, n):
    if n % 1!=0:
        return Power2(a, n)
    else:
        return Power1(a, n)
a = float(input("a = "))
n = float(input("n = "))
print(Power3(a ,n))
# Out:
# 1024.0

# %%
# funksiya 40
def Exp1(x, e):
    s = 1 if e < 1 else 0
    p = 1
    i = 1
    while e < x**i/p :
        p *= i        
        s += x**i/p
        i += 1
        
    return s

x = float(input("x = "))
e = float(input("e = "))
print(Exp1(x,e))
# Out:
# 53.44310405643739

# %%
# funksiya 41
def sin1(x,e):
    s  = 0
    hadi = x; ishora = 1
    f = 1; i = 1
    while hadi > e:
        s += ishora * hadi
        f *= (2*i) * (2*i+1)
        hadi = x**(2*i+1) / f
        ishora *= -1
        i+=1
    return s

x = float(input("x = "))
e = float(input("e = "))
print(sin1(x,e))
# Out:
# 0

# %%
# funksiya 42 
def cos1(x, e):
    s = 1 if e < 1 else 0
    ishora = -1
    p = 1
    i = 2
    while  x**i/p > e:
        p *= (i - 1) * i
        s += ishora * x**i / p
        ishora *= -1
        i += 2 
    return s
x = float(input("x = "))
e = float(input("e = "))
print(cos1(x, e))
# Out:
# -1.6857848324515

# %%
# funksiya 43
def Ln1(x, e):
    s = x if x > e else 0
    ishora = -1
    i = 2
    while x**i/i > e:
        s += ishora * x**i / i
        ishora *= -1
        i += 1
    return s
x = float(input("x = "))
e = float(input("e = "))
print(Ln1(x, e))
# Out:
# 0.4

# %%
# funksiya 44
def Arctg1(x, e):
    s = x if x > e else 0
    ishora = -1
    i = 3
    while x**i/i > e: 
        s += ishora * x**i / i
        ishora *= -1
        i += 2
    return s
x = float(input("x = "))
e = float(input("e = "))
print(Arctg1(x, e))
# Out:
# 0.4

# %%
# funksiya 45
def Power4(x, a, e):
    s = 1 if e < 1 else 0
    p = 1
    i = 1
    p1 = a
    while p1*x/i > e: 
        s += p1 * x / p
        p1 *= a - i + 1
        i += 1
        p *= i
    return s
x = float(input("x = "))
a = float(input("a = "))
e = float(input("e = "))
print(Power4(x, a, e))
# Out:
# 210.00000000000003

# %%
# funksiya 46 
def ekub(a, b):
    while a != b:
        if a > b:
            a -= b
        else:
            b -= a
    return a, b
a = int(input("a = "))
b = int(input("b = "))
print(ekub(a, b))
# Out:
# (1, 1)

# %%
# funksiya 47 
def Frac1(a, b):
    q = a
    p = b
    while a != b:
        if a > b:
            a -= b
        else:
            b -= a 
    p /= a
    q /= a
    return q,p
a = int(input("a = "))
b = int(input("b = "))
print(Frac1(a, b))
# Out:
# (4.0, 5.0)

# %%
# funksiya 48 
def EKUK(a, b):
    p = a*b
    while a != b:
        if a > b:
            a -= b
        else:
            b -= a
    return p / a
a = int(input("a = "))
b = int(input("b = "))
print(EKUK(a, b))
# Out:
# 28.0

# %%
# funksiya 49 
def EKUK3(a, b, c):
    p = a*b*c
    while a != b:
        if a > b:
            a %=b
        else:
            b %=a
        if a ==0:
            a = b
        if b == 0:
            b = a
            
    while a != c:
        if a > c:
            a %= c
        else:
            c %= a
                
        if a==0:
            a =c
        if c == 0:
            c = a
        
    return p/a
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
print(EKUK3(a, b, c))
# Out:
# 20.0

# %%
# funksiya 50 
def TimeToHMS(t):
    hh = t // 3600
    mm = t % 3600 // 60
    ss = t % 60
    return str(hh) +":"+str(mm)+":"+str(ss)
t = int(input("sekunt = "))
print(TimeToHMS(t))
# Out:
# 0:0:4

# %%
# funksiya 51 
def TimeToHMS(t):
    hh = t // 3600
    mm = t % 3600 // 60
    ss = t % 60
    return str(hh) +":"+str(mm)+":"+str(ss)
t = int(input("sekunt = "))
print(TimeToHMS(t))
# Out:
# 0:0:54

# %%
# funksiya 52 
def IsLeapYear(Y):
    if y % 4 == 0 and y % 400 == 0 or y % 4 == 0 and y % 100 !=0:
        return True
    else:
        return False
y = int(input("yil = "))
print(IsLeapYear(y))
# Out:
# True

# %%
# funksiya 53 
def MonthDays(m,y):
    kabisa  = False
    if y % 4 == 0 and y % 400 == 0 or y % 4 == 0 and y % 100 !=0:
        kabisa = True
    if 1 <= m <= 12:
        if m == 2:
            return 28 + kabisa
        elif m == 4 or m == 6 or m == 9 or m == 11:
            return 30
        else:
            return 31
    else:
        return "Kiritilgan sana xato!!!"
y = int(input("yil = "))
m = int(input("oy = "))
print(MonthDays(m, y))
# Out:
# 31

# %%
# funksiya  54 
def PrevDate(dd, mm, yy):
    kabisa  = 0
    if yy % 4 == 0 and yy % 400 == 0 or yy % 4 == 0 and yy % 100 !=0:
        kabisa = 1
    sana = 0
    
    if mm == 2 and 1 <= dd <= 28 + kabisa:
        sana = 1
    elif (mm == 4 or mm == 6 or mm == 9 or mm == 11) and 1 <= dd <= 30:
        sana = 1
    elif (mm == 1 or mm == 3 or mm == 5 or mm == 7 or mm == 8 or mm == 10 or mm == 12) and 1 <= dd <= 31:
        sana =  1
        
    if sana:
        dd -= 1
        if mm == 3 and dd == 0:
            dd = 28 + kabisa
            mm -= 1
        elif (mm == 4 or mm == 6 or mm == 9 or mm == 11) and dd == 0:
            dd = 31
            mm -= 1
        elif (mm == 1 or mm == 3 or mm == 5 or mm == 7 or mm == 8 or mm == 10 or mm == 12) and dd == 0:
            if mm == 1:
                yy -= 1
                mm = 12
                dd = 31
            else:
                mm -= 1
                dd = 30
        return str(dd) + ":" + str(mm) + ":" + str(yy)
        
        
    else:
        return "Kiritilgan sana xato!!!"
d = int(input("kun = "))
m = int(input("oy  = "))
y = int(input("yil = "))
print(PrevDate(d, m, y))
# Out:
# 23:9:2006

# %%
# funksiya 55 
def IsLeapYear(Y):
    if y % 4 == 0 and y % 400 == 0 or y % 4 == 0 and y % 100 !=0:
        return True
    else:
        return False
def MonthDays(k,m,y):
    kabisa  = IsLeapYear(y)    
    if 1 <= m <= 12:
        if m == 2:
            return 1 <= k <= 28 + kabisa
        elif m == 4 or m == 6 or m == 9 or m == 11:
            return 1 <= k <= 30
        else:
            return 1 <= k <=31
    else:
        return False    
def NextDate(dd, mm, yy):
    kabisa  = IsLeapYear(yy)
    sana = MonthDays(dd,mm,yy)
    if sana:
        dd += 1
        if mm == 2 and dd > 28+kabisa:
            mm += 1
            dd %= (28+kabisa)
        elif (mm == 4 or mm == 6 or mm == 9 or mm == 11) and dd > 30:
            mm += 1
            dd %= 30
        elif dd > 31:
            if mm == 12:
                mm = 1
                yy += 1
            else:
                mm +=1 
            dd %= 31
        return str(dd) + ":" + str(mm) + ":" + str(yy)      
    else:
        return "Kiritilgan sana xato!!!"
d = int(input("kun = "))
m = int(input("oy  = "))
y = int(input("yil = "))
print(NextDate(d, m, y))
# Out:
# 15:5:2012

# %%
# funksiya 56 
def Leng(x1,y1, x2, y2):
    return (abs(x1-x2)**2 + abs(y1-y2)**2)**0.5
Ax = int(input("Ax = "))
Ay = int(input("Ay = "))
Bx = int(input("Bx = "))
By = int(input("By = "))
Cx = int(input("Cx = "))
Cy = int(input("Cy = "))
Dx = int(input("Dx = "))
Dy = int(input("Dy = "))
print("|AB| = ", Leng(Ax, Ay, Bx, By))
print("|AC| = ", Leng(Ax, Ay, Cx, Cy))
print("|AD| = ", Leng(Ax, Ay, Dx, Dy))
# Out:
# |AB| =  0.0
# |AC| =  5.0
# |AD| =  2.0

# %%
# funksiya 57 
def Perim(Ax, Ay, Bx, By, Cx, Cy):
    AB = (abs(Ax - Bx)**2 + abs(Ay + By)**2)**0.5
    AC = (abs(Ax - Cx)**2 + abs(Ay + Cy)**2)**0.5
    BC = (abs(Cx - Bx)**2 + abs(Cy + By)**2)**0.5
    if AB + AC > BC and AB + BC > AC and AC + BC > AB:
        return AB + AC + BC
    else:
        return "Bu koordinatalardan uchburchak qurib bo'lmaydi!!!"

Ax = int(input("Ax = "))
Ay = int(input("Ay = "))
Bx = int(input("Bx = "))
By = int(input("By = "))
Cx = int(input("Cx = "))
Cy = int(input("Cy = "))
print(Perim(Ax, Ay, Bx, By, Cx, Cy))
# Out:
# 21.7969550450259

# %%
# funksiya 58 
def Area(Ax, Ay, Bx, By, Cx, Cy):
    AB = (abs(Ax - Bx)**2 + abs(Ay + By)**2)**0.5
    AC = (abs(Ax - Cx)**2 + abs(Ay + Cy)**2)**0.5
    BC = (abs(Cx - Bx)**2 + abs(Cy + By)**2)**0.5
    if AB + AC > BC or AB + BC > AC or AC + BC > AB:
        p =  (AB + AC + BC)/2
        return (p*(p-AB)*(p-AC)*(p-BC))**0.5
    else:
        return "Bu koordinatalardan uchburchak qurib bo'lmaydi!!!"
Ax = int(input("Ax = "))
Ay = int(input("Ay = "))
Bx = int(input("Bx = "))
By = int(input("By = "))
Cx = int(input("Cx = "))
Cy = int(input("Cy = "))
print(Area(Ax, Ay, Bx, By, Cx, Cy))
# Out:
# 13.266499161421596

# %%
# funksiya 59 
def Dist(Ax, Ay, Bx, By, Px, Py):
    AB = (abs(Ax - Bx)**2 + abs(Ay + By)**2)**0.5
    AC = (abs(Ax - Px)**2 + abs(Ay + Py)**2)**0.5
    BC = (abs(Px - Bx)**2 + abs(Py + By)**2)**0.5
    if AB + AC > BC or AB + BC > AC or AC + BC > AB:
        p =  (AB + AC + BC)/2
        S = (p*(p-AB)*(p-AC)*(p-BC))**0.5
        return 2*S/AB
    else:
        return "Kiritilgan koordinatalar xato!!!"

Ax = int(input("Ax = "))
Ay = int(input("Ay = "))
Bx = int(input("Bx = "))
By = int(input("By = "))
Cx = int(input("Px = "))
Cy = int(input("Py = "))
print(Dist(Ax, Ay, Bx, By, Cx, Cy))
# Out:
# 4.361998054450165

# %%
# 60 
def Leng(x1,y1, x2, y2):
    return (abs(x1-x2)**2 + abs(y1-y2)**2)**0.5

def Perim(AB, AC , BC):    
    if AB + AC > BC and AB + BC > AC and AC + BC > AB:
        return AB + AC + BC
    else:
        return 0
    
def Area(AB,AC,BC):
    if AB + AC > BC or AB + BC > AC or AC + BC > AB:
        p =  Perim(AB,AC,BC)/2
        return (p*(p-AB)*(p-AC)*(p-BC))**0.5
    else:
        return 0
    
def Dist(AB,AC,P):
    return 2*Area(AB,AC,P)/AB   
    
def Heights(Ax, Ay, Bx, By, Cx, Cy):
    AB = Leng(Ax,Ay,Bx,By)
    AC = Leng(Ax,Ay,Cx,Cy)
    BC = Leng(Cx,Cy,Bx,By)
    return 2*Area(AB,AC,BC)/AB, 2*Area(AB,AC,BC)/AC, 2*Area(AB,AC,BC)/BC
  
    
Ax = int(input("Ax = "))
Ay = int(input("Ay = "))
Bx = int(input("Bx = "))
By = int(input("By = "))
Cx = int(input("Cx = "))
Cy = int(input("Cy = "))
print(Heights(Ax, Ay, Bx, By, Cx, Cy))
# Out:
# (3.9999999999999916, 0.7999999999999983, 0.707106781186546)
